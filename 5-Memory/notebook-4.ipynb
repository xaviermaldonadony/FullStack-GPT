# %%
from langchain.memory import ConversationKGMemory
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(temperature=0.1)

memory = ConversationKGMemory(
    llm=llm,
    return_messages=True
)

def add_message(input, output):
    memory.save_context({"input":input},{"output": output})

# def get_history():
#     return memory.load_memory_variables({})

add_message("Hi I'm Xavi, I live in NYC", "Wow that is cool!")

# %%
memory.load_memory_variables({"input": "who is Xavi"})
# Out:
# {'history': [SystemMessage(content='On Xavi: Xavi lives in NYC.')]}

# %%
add_message("Xavi like pizza", "wow that is cool!!")

# %%
memory.load_memory_variables({"input": "what does Xavier like"})
# Out:
# {'history': []}
