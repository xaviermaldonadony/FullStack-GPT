# %%
from langchain.memory import ConversationSummaryMemory
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(temperature=0.1)

memory = ConversationSummaryMemory(llm=llm)

def add_message(input, output):
    memory.save_context({"input":input},{"outputs": output})

def get_history():
    return memory.load_memory_variables({})

add_message("Hi I'm Xavi, I live in NYC", "Wow that is cool!")

# %%
add_message("NYC is so pretty", "I wish could go!!")

# %%
get_history()
# Out:
# {'history': 'Xavi introduces themselves and mentions they live in NYC. The AI expresses admiration for that fact and wishes it could visit the city.'}
