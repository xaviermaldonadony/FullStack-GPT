# %%
from langchain.memory import ConversationSummaryBufferMemory
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(temperature=0.1)

memory = ConversationSummaryBufferMemory(
    llm=llm,
    max_token_limit=150,
    return_messages=True
)

def add_message(input, output):
    memory.save_context({"input":input},{"output": output})

def get_history():
    return memory.load_memory_variables({})

add_message("Hi I'm Xavi, I live in NYC", "Wow that is cool!")

get_history()
# Out:
# {'history': [HumanMessage(content="Hi I'm Xavi, I live in NYC"),
#   AIMessage(content='Wow that is cool!')]}

# %%
add_message("NYC is so pretty", "I wish could go!!")
get_history()
# Out:
# {'history': [HumanMessage(content="Hi I'm Xavi, I live in NYC"),
#   AIMessage(content='Wow that is cool!'),
#   HumanMessage(content='NYC is so pretty'),
#   AIMessage(content='I wish could go!!')]}

# %%
add_message("How far is NYC from Argentina", "I don't know!, super far!!")
get_history()
# Out:
# {'history': [HumanMessage(content="Hi I'm Xavi, I live in NYC"),
#   AIMessage(content='Wow that is cool!'),
#   HumanMessage(content='NYC is so pretty'),
#   AIMessage(content='I wish could go!!'),
#   HumanMessage(content='How far is NYC from Argentina'),
#   AIMessage(content="I don't know!, super far!!")]}

# %%
add_message("How far is NYC from Brazil", "I don't know!, super far!!")
get_history()
# Out:
# {'history': [HumanMessage(content="Hi I'm Xavi, I live in NYC"),
#   AIMessage(content='Wow that is cool!'),
#   HumanMessage(content='NYC is so pretty'),
#   AIMessage(content='I wish could go!!'),
#   HumanMessage(content='How far is NYC from Argentina'),
#   AIMessage(content="I don't know!, super far!!"),
#   HumanMessage(content='How far is NYC from Brazil'),
#   AIMessage(content="I don't know!, super far!!")]}

# %%
add_message("How far is NYC from Brazil", "I don't know!, super far!!")
get_history()
# Out:
# {'history': [HumanMessage(content="Hi I'm Xavi, I live in NYC"),
#   AIMessage(content='Wow that is cool!'),
#   HumanMessage(content='NYC is so pretty'),
#   AIMessage(content='I wish could go!!'),
#   HumanMessage(content='How far is NYC from Argentina'),
#   AIMessage(content="I don't know!, super far!!"),
#   HumanMessage(content='How far is NYC from Brazil'),
#   AIMessage(content="I don't know!, super far!!"),
#   HumanMessage(content='How far is NYC from Brazil'),
#   AIMessage(content="I don't know!, super far!!")]}

# %%
add_message("How far is NYC from Brazil", "I don't know!, super far!!")
get_history()
# Out:
# {'history': [HumanMessage(content="Hi I'm Xavi, I live in NYC"),
#   AIMessage(content='Wow that is cool!'),
#   HumanMessage(content='NYC is so pretty'),
#   AIMessage(content='I wish could go!!'),
#   HumanMessage(content='How far is NYC from Argentina'),
#   AIMessage(content="I don't know!, super far!!"),
#   HumanMessage(content='How far is NYC from Brazil'),
#   AIMessage(content="I don't know!, super far!!"),
#   HumanMessage(content='How far is NYC from Brazil'),
#   AIMessage(content="I don't know!, super far!!"),
#   HumanMessage(content='How far is NYC from Brazil'),
#   AIMessage(content="I don't know!, super far!!")]}

# %%
add_message("How far is NYC from Brazil", "I don't know!, super far!!")
get_history()
# Out:
# {'history': [SystemMessage(content='The human introduces themselves as Xavi from NYC. The AI responds with enthusiasm, saying that it is cool.'),
#   HumanMessage(content='NYC is so pretty'),
#   AIMessage(content='I wish could go!!'),
#   HumanMessage(content='How far is NYC from Argentina'),
#   AIMessage(content="I don't know!, super far!!"),
#   HumanMessage(content='How far is NYC from Brazil'),
#   AIMessage(content="I don't know!, super far!!"),
#   HumanMessage(content='How far is NYC from Brazil'),
#   AIMessage(content="I don't know!, super far!!"),
#   HumanMessage(content='How far is NYC from Brazil'),
#   AIMessage(content="I don't know!, super far!!"),
#   HumanMessage(content='How far is NYC from Brazil'),
#   AIMessage(content="I don't know!, super far!!")]}
