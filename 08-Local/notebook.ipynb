# %%
from langchain.llms.huggingface_pipeline import HuggingFacePipeline
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template("A {word} is a")

llm = HuggingFacePipeline.from_model_id(
   model_id="gpt2",
   task="text-generation",
   pipeline_kwargs={
      "max_new_tokens": 50
   }
)

chain = prompt | llm

# This should execute successfully against the hosted API
result = chain.invoke({
   "word": "potato",
})

print(result)
# Out:
# Downloading tokenizer_config.json: 100%|██████████| 26.0/26.0 [00:00<00:00, 25.7kB/s]
# Downloading config.json: 100%|██████████| 665/665 [00:00<00:00, 3.11MB/s]
# Downloading vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 17.9MB/s]
# Downloading merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 24.4MB/s]
# Downloading tokenizer.json: 100%|██████████| 1.36M/1.36M [00:00<00:00, 30.9MB/s]
# Downloading model.safetensors: 100%|██████████| 548M/548M [00:17<00:00, 31.9MB/s]
# Downloading generation_config.json: 100%|██████████| 124/124 [00:00<00:00, 226kB/s]
# Using pad_token, but it is not set yet.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  small, medium sized fruit that is kept in an upright or upright container. It should ideally be kept moist (at least for as long as you are eating) or as long as you are eating on the part of the child. (It is not
